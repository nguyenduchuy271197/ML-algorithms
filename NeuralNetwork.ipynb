# %%
import numpy as np
#w1: 
class NeuralNetwork:
  def __init__(self, n_in, n_hidden, n_out):
    self.n_in = n_in
    self.n_hidden = n_hidden
    self.n_out = n_out

    self.w1 = None
    self.w2 = None

  def weigth_init(self):
    self.w1 = np.random.rand(self.n_hidden, self.n_in)*np.sqrt(2.0/n_in)
    self.w2 = np.random.rand(self.n_out, self.n_hidden)*np.sqrt(2.0/n_hidden)
    return self.w1, self.w2

  def relu(self, x):
    return np.where(x>=0, x, 0)
  
  def relu_derivative(x):
    x = np.where(x<=0, x, 1)
    x = np.where(x>0, x, 0)
    return x

  def sigmoid(self, x):
    return 1/(1+np.exp(-x))

  def sigmoid_derivative(self, x):
    return self.sigmoid(x)*(1-self.sigmoid(x))

  def A1(self):
    return self.relu(np.dot(self.w1, A0))

  def A2(self, A0):
    A2 = self.sigmoid(np.dot(self.w2, self.A1)
    return A2

  def loss(self, A2, y):pass
    L = y*np.log(A2)+(1-y)*np.log(1-A2)
    return L

  def backpropagation(self):
    dL_dw2 = np.dot((y-self.A2)*self.A1.T)/self.m
    dL_dw1 = 

  def para_update(self):
    pass

# %%
def relu_derivative(x):
  x = np.where(x<=0, x, 1)
  x = np.where(x>0, x, 0)
  return x
x = np.array([[0, 1, 2],
       [0, 0.5, -2],
       [-1, 0.6, 6]])

relu_derivative(x)
# Out:
# array([[0., 1., 1.],
#        [0., 1., 0.],
#        [0., 1., 1.]])
